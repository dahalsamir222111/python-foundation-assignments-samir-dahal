# %%
"""
Exercise: Dataset Access Decision
Student: Samir Dahal
Day: 1
"""

# Define rules
allowed_roles = ["analyst", "scientist", "engineer"]
restricted_datasets = ["salary_data", "personal_data"]

print("=" * 60)
print("DATASET ACCESS CONTROL SYSTEM")
print("=" * 60)

# Scenario 1: Analyst with sales data - Should be ALLOWED
print("\n SCENARIO 1")
print("-" * 40)
user_role = "analyst"
is_active = True
requested_dataset = "sales_data"

print(f"Role: {user_role}")
print(f"Active: {is_active}")
print(f"Dataset: {requested_dataset}")

if not is_active:
    print(" Access denied because the user is inactive.")
elif user_role not in allowed_roles:
    print(" Access denied because the role is not allowed.")
elif requested_dataset in restricted_datasets:
    print(" Access denied because the dataset is restricted.")
else:
    print(" Access granted! User can access the dataset.")

# Scenario 2: Inactive engineer - Should be DENIED
print("\n SCENARIO 2")
print("-" * 40)
user_role = "engineer"
is_active = False
requested_dataset = "sales_data"

print(f"Role: {user_role}")
print(f"Active: {is_active}")
print(f"Dataset: {requested_dataset}")

if not is_active:
    print(" Access denied because the user is inactive.")
elif user_role not in allowed_roles:
    print(" Access denied because the role is not allowed.")
elif requested_dataset in restricted_datasets:
    print(" Access denied because the dataset is restricted.")
else:
    print(" Access granted! User can access the dataset.")

# Scenario 3: Scientist with restricted data - Should be DENIED
print("\n SCENARIO 3")
print("-" * 40)
user_role = "scientist"
is_active = True
requested_dataset = "salary_data"

print(f"Role: {user_role}")
print(f"Active: {is_active}")
print(f"Dataset: {requested_dataset}")

if not is_active:
    print(" Access denied because the user is inactive.")
elif user_role not in allowed_roles:
    print(" Access denied because the role is not allowed.")
elif requested_dataset in restricted_datasets:
    print(" Access denied because the dataset is restricted.")
else:
    print(" Access granted! User can access the dataset.")

# Scenario 4: Manager (not allowed role) - Should be DENIED
print("\n SCENARIO 4")
print("-" * 40)
user_role = "manager"
is_active = True
requested_dataset = "sales_data"

print(f"Role: {user_role}")
print(f"Active: {is_active}")
print(f"Dataset: {requested_dataset}")

if not is_active:
    print(" Access denied because the user is inactive.")
elif user_role not in allowed_roles:
    print(" Access denied because the role is not allowed.")
elif requested_dataset in restricted_datasets:
    print("Access denied because the dataset is restricted.")
else:
    print(" Access granted! User can access the dataset.")

# Scenario 5: Analyst with personal data - Should be DENIED
print("\n SCENARIO 5")
print("-" * 40)
user_role = "analyst"
is_active = True
requested_dataset = "personal_data"

print(f"Role: {user_role}")
print(f"Active: {is_active}")
print(f"Dataset: {requested_dataset}")

if not is_active:
    print(" Access denied because the user is inactive.")
elif user_role not in allowed_roles:
    print(" Access denied because the role is not allowed.")
elif requested_dataset in restricted_datasets:
    print(" Access denied because the dataset is restricted.")
else:
    print(" Access granted! User can access the dataset.")

# Summary
print("\n" + "=" * 60)
print("SUMMARY")
print("=" * 60)
print(" Scenario 1: Analyst + Active + Sales Data → ALLOWED")
print(" Scenario 2: Engineer + Inactive + Sales Data → DENIED (Inactive)")
print(" Scenario 3: Scientist + Active + Salary Data → DENIED (Restricted)")
print(" Scenario 4: Manager + Active + Sales Data → DENIED (Role not allowed)")
print(" Scenario 5: Analyst + Active + Personal Data → DENIED (Restricted)")
# Out:
# ============================================================
# DATASET ACCESS CONTROL SYSTEM
# ============================================================
#
#  SCENARIO 1
# ----------------------------------------
# Role: analyst
# Active: True
# Dataset: sales_data
#  Access granted! User can access the dataset.
#
#  SCENARIO 2
# ----------------------------------------
# Role: engineer
# Active: False
# Dataset: sales_data
#  Access denied because the user is inactive.
#
#  SCENARIO 3
# ----------------------------------------
# Role: scientist
# Active: True
# Dataset: salary_data
#  Access denied because the dataset is restricted.
#
#  SCENARIO 4
# ----------------------------------------
# Role: manager
# Active: True
# Dataset: sales_data
#  Access denied because the role is not allowed.
#
#  SCENARIO 5
# ----------------------------------------
# Role: analyst
# Active: True
# Dataset: personal_data
#  Access denied because the dataset is restricted.
#
# ============================================================
# SUMMARY
# ============================================================
#  Scenario 1: Analyst + Active + Sales Data → ALLOWED
#  Scenario 2: Engineer + Inactive + Sales Data → DENIED (Inactive)
#  Scenario 3: Scientist + Active + Salary Data → DENIED (Restricted)
#  Scenario 4: Manager + Active + Sales Data → DENIED (Role not allowed)
#  Scenario 5: Analyst + Active + Personal Data → DENIED (Restricted)

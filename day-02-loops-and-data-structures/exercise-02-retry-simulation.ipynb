# %%
"""
Exercise: Retry Simulation
Student: Samir Dahal
Day: 2
"""

# Variables
attempt = 1
max_attempts = 3
operation_successful = False

# While loop for retry attempts
while attempt <= max_attempts:
    print(f"Attempt {attempt}")
    
    # Simulate success on attempt 2 (for stretch)
    if attempt == 2:
        operation_successful = True
        break  # Stop early if successful
    
    attempt = attempt + 1

# Display final result
if operation_successful:
    print("Operation completed successfully")
else:
    print("Operation failed after three attempts")
# Out:
# Attempt 1
# Attempt 2
# Operation completed successfully

# %%
##Changing the attemp from 2 to 1

# %%
"""
Exercise: Retry Simulation
Student: Samir Dahal
Day: 2
"""

# Variables
attempt = 1
max_attempts = 3
operation_successful = False

# While loop for retry attempts
while attempt <= max_attempts:
    print(f"Attempt {attempt}")
    
    # Simulate success on attempt 2 (for stretch)
    if attempt == 1:
        operation_successful = True
        break  # Stop early if successful
    
    attempt = attempt + 1

# Display final result
if operation_successful:
    print("Operation completed successfully")
else:
    print("Operation failed after three attempts")
# Out:
# Attempt 1
# Operation completed successfully
